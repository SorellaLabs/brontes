# %%
import polars as pl

def load_and_aggregate(path_to_blocks, path_to_bundles):
    # Load the parquet files into Polars DataFrames
    blocks_df = pl.read_parquet(path_to_blocks)
    bundles_df = pl.read_parquet(path_to_bundles)

    # Aggregate PNL by unique builder using 'builder_address' and 'builder_profit_usd'
    pnl_by_builder = blocks_df.groupby("builder_address").agg([
        pl.col("builder_profit_usd").sum().alias("total_builder_profit_usd")
    ])

    # Aggregate PNL by unique searcher using 'eoa' and 'profit_usd'
    pnl_by_searcher = bundles_df.groupby("eoa").agg([
        pl.col("profit_usd").sum().alias("total_searcher_profit_usd")
    ])

    return pnl_by_builder, pnl_by_searcher

if __name__ == "__main__":
    path_to_blocks = "db/parquet/block_table.parquet"
    path_to_bundles = "db/parquet/bundle_table.parquet"

    pnl_by_builder, pnl_by_searcher = load_and_aggregate(path_to_blocks, path_to_bundles)

    # Optionally, print the results
    print("PNL by Builder:")
    print(pnl_by_builder)
    print("\nPNL by Searcher:")
    print(pnl_by_searcher)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 24
#      21 path_to_blocks = "db/parquet/block_table.parquet"
#      22 path_to_bundles = "db/parquet/bundle_table.parquet"
# ---> 24 pnl_by_builder, pnl_by_searcher = load_and_aggregate(path_to_blocks, path_to_bundles)
#      26 # Optionally, print the results
#      27 print("PNL by Builder:")
#
# Cell In[1], line 5, in load_and_aggregate(path_to_blocks, path_to_bundles)
#       3 def load_and_aggregate(path_to_blocks, path_to_bundles):
#       4     # Load the parquet files into Polars DataFrames
# ----> 5     blocks_df = pl.read_parquet(path_to_blocks)
#       6     bundles_df = pl.read_parquet(path_to_bundles)
#       8     # Aggregate PNL by unique builder using 'builder_address' and 'builder_profit_usd'
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/polars/io/parquet/functions.py:124, in read_parquet(source, columns, n_rows, use_pyarrow, memory_map, storage_options, parallel, row_count_name, row_count_offset, low_memory, pyarrow_options, use_statistics, rechunk)
#     113     import pyarrow.parquet
#     115     return from_arrow(  # type: ignore[return-value]
#     116         pa.parquet.read_table(
#     117             source_prep,
#    (...)
#     121         )
#     122     )
# --> 124 return pli.DataFrame._read_parquet(
#     125     source_prep,
#     126     columns=columns,
#     127     n_rows=n_rows,
#     128     parallel=parallel,
#     129     row_count_name=row_count_name,
#     130     row_count_offset=row_count_offset,
#     131     low_memory=low_memory,
#     132     use_statistics=use_statistics,
#     133     rechunk=rechunk,
#     134 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/polars/dataframe/frame.py:863, in DataFrame._read_parquet(cls, source, columns, n_rows, parallel, row_count_name, row_count_offset, low_memory, use_statistics, rechunk)
#     861 projection, columns = handle_projection_columns(columns)
#     862 self = cls.__new__(cls)
# --> 863 self._df = PyDataFrame.read_parquet(
#     864     source,
#     865     columns,
#     866     projection,
#     867     n_rows,
#     868     parallel,
#     869     _prepare_row_count_args(row_count_name, row_count_offset),
#     870     low_memory=low_memory,
#     871     use_statistics=use_statistics,
#     872     rechunk=rechunk,
#     873 )
#     874 return self
#
# FileNotFoundError: No such file or directory: db/parquet/block_table.parquet
